# %%
import pandas as pd
import shapely.wkb
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Point

# %%
data_50001 = pd.read_parquet("../base.data/50001.parquet")
data_50001
# Out:
#   DPTOMPIO DPTO_CCDGO MPIO_CCDGO MPIO_CNMBR MPIO_CCNCT  \
# 0    05001         05        001   MEDELLÍN      05001
#
#                                             geometry
# 0  b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x8e\x04...

# %%
wkb_data_med = data_50001.iloc[0,5]

# %%
wkb_data_med
# Out:
# b'\x01\x03\x00\x00\x00\x01\x00\x00\x00\x8e\x04\x00\x00e\xfd\xa8~\xcc\xeaR\xc0K\xf8\xf1\x0c$~\x19@B\xca4\x9f\xd5\xeaR\xc0w\x9c\xd3\x0ez~\x19@\xf5H^^\xdf\xeaR\xc0\x03\x05@\xaa\x9b~\x19@\x82\xa5\xe9\x02\xea\xeaR\xc0{3\x0cH\x90~\x19@\xd6*\x0b\x03\xef\xeaR\xc0\xe3\x91\xf0\x18y~\x19@cf%\x01\xf8\xeaR\xc0+VS\x01\x13~\x19@\x12@+B\x07\xebR\xc0\x97\xb3\x86q\x88}\x19@?\\v\xde\x1f\xebR\xc07[j\x10(}\x19@@*#\x00(\xebR\xc0\x07v\\\xb0\xfb|\x19@\xc7y\x80\xa0<\xebR\xc0\x97\xe5\x0c\x88\xba|\x19@\xb7^\xf2#D\xebR\xc0/\x8d,a\xb9|\x19@\xc3\xa5uDS\xebR\xc0S\xf1"\xd4\x8b|\x19@js)b\\\xebR\xc0\xbb\x96\xbe\xafH|\x19@w\xe3\xe7\x03e\xebR\xc07\xd87\x11\xac{\x19@\xb6\xadE"l\xebR\xc0\x1b\xf7\x90\xca\xf6z\x19@\xe2\x178\x82o\xebR\xc0_\xe8(\xf3\xcez\x19@\tn\x1c\xc5z\xebR\xc07\xdf\xea\xc9\x94z\x19@\xb8;\x97\x81\x81\xebR\xc0\x1b\xceq\x99\x93z\x19@zs\xbf\xa3\x83\xebR\xc0\xef\x08E\xffsz\x19@\x0f\xb0\xccD\x99\xebR\xc0\xa7\\f\xbf\x8bz\x19@\xb7\xc3MC\xbd\xebR\xc0\xe7V\xb5b\x87z\x19@+\xcfr"\xdf\xebR\xc0\xf7d\x05\x87cz\x19@\xd1\x0b\xb4$\xe8\xebR\xc0\x03\x0b\xfewwz\x19@\xf9\x07v\x01\xf1\xebR\xc0\x7fT.\x87\xefz\x19@y\x9f7\xa3\xf3\xebR\xc0\x87\xbb\xd8?E{\x19@^ \xae \xf6\xebR\xc0s\xbf\x85!\xe4{\x19@\x0f4\xeb\x01\xfd\xebR\xc0\x13.\xea5k|\x19@\xce$\xf7\xc2\x04\xecR\xc0\x83|\xc3^\xd7|\x19@Iv\x95\x83\x13\xecR\xc0\xfb i\x0f2}\x19@}\xcc\xe9@#\xecR\xc0s\xc4W\xe5\x89|\x19@H.Y$,\xecR\xc0_\xedx\x7f\xfb{\x19@\xccd\'\x05;\xecR\xc0CO\x01\xb9\x8f{\x19@\xd4\x80\xcc\xc4P\xecR\xc0\xf7\xab\xf7\xb1\x08{\x19@Kq\x04%\\\xecR\xc0\xbb:T\x02Kz\x19@\xf8r:\x84b\xecR\xc07\xd2\xc7\xee\x95z\x19@\xa3\x7f\xf6\xe1h\xecR\xc0\x7f\x97\x18\xec\x02{\x19@:\xbcE\xc5w\xecR\xc0\xd7\x14\x15\xc59{\x19@\xbey\xaaC\x8e\xecR\xc0K\xebA>q{\x19@\x87p\xaf\xa6\x94\xecR\xc0\xfb\xeb\xee\xe3c{\x19@-\x970\xa7\x9f\xecR\xc0\x07\x01~I\x07|\x19@\xd6.\xfb\xe2\xa3\xecR\xc0o\xa9\xd2o\x8f|\x19@\x0e\x84\xd2\xe7\xa8\xecR\xc0\xff\xa99\xed\xe7|\x19@+I\xc2D\xb7\xecR\xc0\xa39\xed\xa0G}\x19@\x1b\xb5"g\xca\xecR\xc0\xf7\x8d\x1b\xb1(~\x19@\xc3s e\xd0\xecR\xc0\xe7\xf4]\xac\xd0}\x19@\x1dY\xed\x85\xd5\xecR\xc0\xe7\x9d\xf8\x8dV}\x19@\xafnse\xdb\xecR\xc0?\x06\x019.}\x19@\xd7I\xd6\xa4\xe5\xecR\xc0\xafnH\x9eI}\x19@\x0e\\\xc7F\xed\xecR\xc0+\x1cxC\x87}\x19@\xde\x93`\x07\xf4\xecR\xc0\x0f5y-\x95}\x19@\x18\x89\x16\'\xfe\xecR\xc0os\x83\xcc\x8e}\x19@b\xcb2$\x04\xedR\xc0SH&\xecJ}\x19@\x13\xe6OD\x14\xedR\xc0?\xde\xec\x07#}\x19@\xe3\'p\xa6\x1a\xedR\xc0G\xd5\x8a\x1d*}\x19@\x90\xfb\xa5\xc4\x1c\xedR\xc0W2n:g}\x19@\'\x16\x03G)\xedR\xc0\xbf\x96:\x9dk}\x19@G\xfd\x7fF0\xedR\xc0c\xd5Y\xbbZ}\x19@\x15=\x0e\x88R\xedR\xc0o\xe2\xa0\x87Q}\x19@\xa9\xff\x15\'n\xedR\xc0\x7f\xc8\x83\x9c\x13}\x19@\x08lq\x07v\xedR\xc0_w\x91\x02>}\x19@\xd9\xe2\xb3\x05|\xedR\xc0;P\xdd\xc4\xdf|\x19@\x86\x94I\xe7\x85\xedR\xc0\x8b\x90\x9d\x91\xea|\x19@\xff\x96\xd8\xc6\x89\xedR\xc0\xb3wH\\\xc0|\x19@&\xccx\xe4\x9a\xedR\xc0\xab\x86\x8cLb|\x19@C\xbev)\xa8\xedR\xc0\xe7\xe4\x17\x81X|\x19@\t^\xd1\x06\xb0\xedR\xc0\xd7E\tb\xef{\x19@\x03Inf\xb7\xedR\xc0[\x9aUe\x00z\x19@\xc8?\x94D\xc3\xedR\xc0\xe3J\x12\x19\x90x\x19@*\x11\x99f\xd8\xedR\xc0s\x8e\xca\x99bv\x19@\xce\x10\xdc\xe8\xe6\xedR\xc0\xeb\x16u\x1d\x12u\x19@F\\\x13G\xe8\xedR\xc0w\x19\xc4#\xcbs\x19@o+\x80f\xe6\xedR\xc0\xaf\xeb\xa6\';r\x19@\xb6\xc9\x8d\'\xe4\xedR\xc0\xabP\rJ\x84q\x19@\xfd\x9e\xa0\xc6\xdd\xedR\xc0\x97HM\xe1_q\x19@i\xf7\xa4F\xda\xedR\xc0\xbf\n\x91\x8a\x01q\x19@\x9a@\xc6F\xda\xedR\xc0\xbb\x9d\x8a\n\x8bp\x19@\x96\xaeH\xc8\xd7\xedR\xc0w\xc9>\xdc\x96o\x19@\xf8\xa9*\xc7\xd3\xedR\xc0c)<\xfb\xd9n\x19@\xd5\x16\xf0(\xd1\xedR\xc0\x87H\xd4>/n\x19@\xc30\xcff\xcf\xedR\xc0\xcb8\x91BTm\x19@\xf9\x8aPg\xcc\xedR\xc0\xaf\xd3\x05R\xe8l\x19@\x84k\x8c\x08\xcc\xedR\xc0/q\xf8\x8bvl\x19@\x80>\x02\xc6\xcd\xedR\xc0\xa7p\x92\x9a\x01l\x19@\xa3\xda\xeaI\xcb\xedR\xc0\xff\xac<y?k\x19@6S g\xc5\xedR\xc0{\xd2\x0c\x81\xdaj\x19@S$Q(\xbe\xedR\xc0\xe3\x1d\x1e\xf21j\x19@\x0eM\xe8\xa7\xb8\xedR\xc0w\xb7\xb1\x8d\x03i\x19@\xa8o\xa9H\xba\xedR\xc0\xd3\x90MR\x96h\x19@*T7\xaa\xc2\xedR\xc0\xfb]9W\xa1h\x19@\x16s+\xa5\xc3\xedR\xc0\xb7\x1d\x87E5h\x19@85\xb4\'\xbf\xedR\xc0[8p\xdeje\x19@\xc5(\x07g\xbb\xedR\ ...

# %%
geometry_med = shapely.wkb.loads(wkb_data_med)

# %%
geometry_med
# Out:
# <POLYGON ((-75.669 6.373, -75.669 6.374, -75.67 6.374, -75.671 6.374, -75.67...>

# %%
print(type(geometry_med))
# Out:
# <class 'shapely.geometry.polygon.Polygon'>

# %%
gdf = gpd.GeoDataFrame([1], geometry=[geometry_med], crs="EPSG:4326")

# %%
gdf.plot()
plt.show()

# %%
barrios = pd.read_parquet("../base.data/medellin_neighborhoods.parquet")
barrios_p = pd.read_parquet("../base.data/datos_por_comuna.parquet")

# %%
barrios['geometry'] = barrios['geometry'].apply(shapely.wkb.loads)
barrios_p['points'] = barrios_p['points'].apply(shapely.wkb.loads)
gdf_comunas = gpd.GeoDataFrame(barrios, geometry='geometry', crs="EPSG:4326")
gdf_comunas_p = gpd.GeoDataFrame(barrios_p, geometry='points', crs="EPSG:4326")

# %%
fig, ax = plt.subplots()

# gdf_comunas.plot(ax=ax, color='blue', alpha=0.5)
gdf_comunas.plot(ax=ax)
gdf_comunas_p.plot(ax=ax, color='red', alpha=0.5, markersize=1)
plt.axis('equal')  # Asegura que los ejes x e y tengan la misma escala
plt.show()

# %%
fig, ax = plt.subplots()

# gdf_comunas.plot(ax=ax, color='blue', alpha=0.5)
gdf_comunas.plot(ax=ax)
gdf_comunas_p.plot(ax=ax, color='red', alpha=0.5, markersize=5)
plt.axis('equal')  # Asegura que los ejes x e y tengan la misma escala
plt.show()

# %%
def generate_random_point_within_polygon(polygon):
    min_x, min_y, max_x, max_y = polygon.bounds
    while True:
        random_point = Point(np.random.uniform(min_x, max_x), np.random.uniform(min_y, max_y))
        if polygon.contains(random_point):
            return random_point

# %%
random_point = generate_random_point_within_polygon(geometry_med)

# %%
gdf_point = gpd.GeoDataFrame([1], geometry=[random_point], crs="EPSG:4326")

# %%
for idx, row in gdf_comunas.iterrows():
    if row['geometry'].contains(random_point):
        print(f"El punto aleatorio está en {row['NOMBRE']}")
        break
# Out:
# El punto aleatorio está en CORREGIMIENTO DE SAN ANTONIO DE PRADO

# %%
base = gdf_comunas.plot(color='white', edgecolor='black')
gdf_point.plot(ax=base, marker='o', color='red', markersize=5)
plt.title("Punto aleatorio dentro de las comunas de Medellín")
plt.show()

# %%
# shapes = list(map(shapely.wkb.loads, barrios["geometry"]))
# barrios["shapes"] = shapes

# %%
# type(barrios["shapes"][0])

# %%
# barrios_map = []
# for shape in shapes:
#     gdf = gpd.GeoDataFrame([1], geometry=[shape], crs="EPSG:4326")
#     barrios_map.append(gdf)

# %%
# barrios["barrios_map"] = barrios_map

# %%
# for map in range(len(barrios["barrios_map"])):
#     barrios["barrios_map"][map].plot()
#     plt.show(barrios["NOMBRE"][map])
