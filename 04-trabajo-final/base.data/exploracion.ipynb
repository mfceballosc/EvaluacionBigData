# %%
import pandas as pd

# %%
df = pd.read_parquet("03042024.parquet")

# %%
df.head(3)
# Out:
#     partition_date                              order_id   commune  \
# 557       03042024  10a44773-85b5-583d-a561-a5458a99a15b  COMUNA 3
# 513       03042024  e85b1471-83a8-57f3-909f-702e120f2def  COMUNA 3
# 565       03042024  49401a7c-0e64-5d92-b303-ae8472ee2409  COMUNA 3
#
#      customer_id  employee_id  event_date event_day event_hour event_minute  \
# 557         4261         1679  2024-04-03        03         23           43
# 513         3340         1679  2024-04-03        03         23           10
# 565         4838         1679  2024-04-03        03         22           42
#
#     event_month event_second event_year   latitude  longitude neighborhood  \
# 557          04           44       2024 -75.549650   6.269627     MANRIQUE
# 513          04           04       2024 -75.546873   6.276826     MANRIQUE
# 565          04           45       2024 -75.546877   6.283064     MANRIQUE
#
#      quantity_products
# 557                  7
# 513                 20
# ...
